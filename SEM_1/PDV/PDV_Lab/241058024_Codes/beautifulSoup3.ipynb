# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://quotes.toscrape.com/page/1/'
response = requests.get(url)

#with open('path_to_your_file.html', 'r', encoding='utf-8') as file:  # Replace with the actual path to your file
    #html_content = file.read()

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
quotes_classes = soup.find_all('div',class_ = 'quote')

# %%
author = []
quotes = []
for quote in quotes_classes:   
    quotes.append(quote.find('span',class_ = 'text').text)
    author.append(quote.find('small',class_='author').text)

# %%
def
# Out:
# ['Albert Einstein',
#  'J.K. Rowling',
#  'Albert Einstein',
#  'Jane Austen',
#  'Marilyn Monroe',
#  'Albert Einstein',
#  'André Gide',
#  'Thomas A. Edison',
#  'Eleanor Roosevelt',
#  'Steve Martin']

# %%
for job in jobs:
    print(job.prettify())

# %%
job_tuple
# Out:
# []

# %%
soup.find_all('a', class_='comp-name')
# Out:
# []

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

# Path to your ChromeDriver (change this if not in your PATH)
chrome_driver_path = 'path/to/chromedriver'  # Replace with actual path to your ChromeDriver

# Initialize the Selenium WebDriver (make sure you have the correct driver version)
driver = webdriver.Chrome(executable_path=chrome_driver_path)

# URL of the page you want to scrape
url = 'https://www.naukri.com/jobs-in-manipal-udupi'

# Open the page using Selenium WebDriver
driver.get(url)

# Wait for a few seconds to ensure the dynamic content has loaded
time.sleep(5)  # Wait for 5 seconds (you may need to adjust this)

# After the page loads, get the page source (HTML) with all the content
page_source = driver.page_source

# Parse the loaded HTML with BeautifulSoup
soup = BeautifulSoup(page_source, 'html.parser')

# Find the job listings on the page (update class names as necessary)
job_listings = soup.find_all('div', class_='cust-job-tuple layout-wrapper lay-2 sjw__tuple')

# Check if job listings were found
if job_listings:
    for job in job_listings:
        job_title = job.find('a', class_='title')['title'] if job.find('a', class_='title') else 'No title'
        company_name = job.find('a', class_='comp-name').text.strip() if job.find('a', class_='comp-name') else 'No company'
        location = job.find('span', class_='locWdth2').text.strip() if job.find('span', class_='locWdth2') else 'No location'
        
        print(f"Job Title: {job_title}")
        print(f"Company Name: {company_name}")
        print(f"Location: {location}")
        print("=" * 50)
else:
    print("No job listings found")

# Close the browser
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 9>()
#       6 chrome_driver_path = 'path/to/chromedriver'  # Replace with actual path to your ChromeDriver
#       8 # Initialize the Selenium WebDriver (make sure you have the correct driver version)
# ----> 9 driver = webdriver.Chrome(executable_path=chrome_driver_path)
#      11 # URL of the page you want to scrape
#      12 url = 'https://www.naukri.com/jobs-in-manipal-udupi'
#
# TypeError: WebDriver.__init__() got an unexpected keyword argument 'executable_path'

# %%
import requests
from bs4 import BeautifulSoup

# Base URL for scraping
base_url = 'https://quotes.toscrape.com/page/{}/'

# Function to scrape quotes from a single page
def scrape_page(page_number):
    url = base_url.format(page_number)
    response = requests.get(url)
    
    if response.status_code != 200:
        print(f"Failed to retrieve page {page_number}")
        return None
    
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract all quotes on the page
    quotes = []
    for quote in soup.find_all('div', class_='quote'):
        text = quote.find('span', class_='text').get_text()
        author = quote.find('small', class_='author').get_text()
        tags = [tag.get_text() for tag in quote.find_all('a', class_='tag')]
        
        quotes.append({
            'text': text,
            'author': author,
            'tags': tags
        })
    
    # Check if there is a "Next" page
    next_button = soup.find('li', class_='next')
    next_page = None
    if next_button:
        next_page = next_button.find('a').get('href')
    
    return quotes, next_page

# Function to scrape all pages
def scrape_all_pages():
    page_number = 1
    all_quotes = []
    
    while True:
        quotes, next_page = scrape_page(page_number)
        
        if quotes:
            all_quotes.extend(quotes)
            print(f"Scraped page {page_number} with {len(quotes)} quotes.")
        else:
            print(f"Failed to scrape page {page_number}.")
            break
        
        # If there is no next page, break the loop
        if not next_page:
            print("No more pages to scrape.")
            break
        
        page_number += 1  # Go to the next page
    
    return all_quotes

# Start scraping
quotes = scrape_all_pages()

# Print all the scraped quotes
for quote in quotes:
    print(f"Quote: {quote['text']}")
    print(f"Author: {quote['author']}")
    print(f"Tags: {', '.join(quote['tags'])}")
    print("=" * 50)
# Out:
# Scraped page 1 with 10 quotes.
# Scraped page 2 with 10 quotes.
# Scraped page 3 with 10 quotes.
# Scraped page 4 with 10 quotes.
# Scraped page 5 with 10 quotes.
# Scraped page 6 with 10 quotes.
# Scraped page 7 with 10 quotes.
# Scraped page 8 with 10 quotes.
# Scraped page 9 with 10 quotes.
# Scraped page 10 with 10 quotes.
# No more pages to scrape.
# Quote: “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# Author: Albert Einstein
# Tags: change, deep-thoughts, thinking, world
# ...
# Quote: “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Author: J.K. Rowling
# Tags: abilities, choices
# ...
# Quote: “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Author: Albert Einstein
# Tags: inspirational, life, live, miracle, miracles
# ...
