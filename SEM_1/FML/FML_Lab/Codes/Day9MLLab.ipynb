# %% [markdown]
# Bagging

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Social_Network_Ads.csv On DTC

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/BDA_1_Sem/FML/FML_Lab/Datasets/Social_Network_Ads.csv')

# Drop the 'User ID' column and encode 'Gender'
data_cleaned = data.drop('User ID', axis=1)
label_encoder = LabelEncoder()
data_cleaned['Gender'] = label_encoder.fit_transform(data_cleaned['Gender'])

# Split the data into features and target
X = data_cleaned.drop('Purchased', axis=1)
y = data_cleaned['Purchased']

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Define the Decision Tree Classifier with entropy
dtc = DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=42)

# Train the model
dtc.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dtc.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(classification_rep)
# Out:
# Accuracy: 0.88
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        63
#            1       0.88      0.78      0.83        37
#
#     accuracy                           0.88       100
#    macro avg       0.88      0.86      0.87       100
# weighted avg       0.88      0.88      0.88       100

# %% [markdown]
# Social_Network_Ads.csv On RFC

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/BDA_1_Sem/FML/FML_Lab/Datasets/Social_Network_Ads.csv')

# Drop the 'User ID' column and encode 'Gender'
data_cleaned = data.drop('User ID', axis=1)
label_encoder = LabelEncoder()
data_cleaned['Gender'] = label_encoder.fit_transform(data_cleaned['Gender'])

# Split the data into features and target
X = data_cleaned.drop('Purchased', axis=1)
y = data_cleaned['Purchased']

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Define the Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)

# Train the model
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
classification_rep_rf = classification_report(y_test, y_pred_rf)

print(f"Accuracy (RF): {accuracy_rf}")
print(classification_rep_rf)
# Out:
# Accuracy (RF): 0.92
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        63
#            1       0.87      0.92      0.89        37
#
#     accuracy                           0.92       100
#    macro avg       0.91      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100

# %%
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standard Scalar
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Define the Random Forest Classifier
rf = RandomForestClassifier(n_estimators=10, max_depth=1, random_state=0)

# Train the model
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
classification_rep_rf = classification_report(y_test, y_pred_rf)

print(f"Accuracy (RF): {accuracy_rf}")
print(classification_rep_rf)
# Out:
# Accuracy (RF): 0.9
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        63
#            1       0.91      0.81      0.86        37
#
#     accuracy                           0.90       100
#    macro avg       0.90      0.88      0.89       100
# weighted avg       0.90      0.90      0.90       100

# %%
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# Standard Scalar
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Define the Random Forest Classifier
rf = RandomForestClassifier(n_estimators=50, max_depth=3, random_state=0)

# Train the model
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
classification_rep_rf = classification_report(y_test, y_pred_rf)

print(f"Accuracy (RF): {accuracy_rf}")
print(classification_rep_rf)
# Out:
# Accuracy (RF): 0.94
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96        68
#            1       0.88      0.94      0.91        32
#
#     accuracy                           0.94       100
#    macro avg       0.93      0.94      0.93       100
# weighted avg       0.94      0.94      0.94       100

# %%
# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Standard Scalar
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Define the Random Forest Classifier
rf = RandomForestClassifier(n_estimators=75, max_depth=3, random_state=0)

# Train the model
rf.fit(X_train, y_train)

# Make predictions on the test set
y_pred_rf = rf.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
classification_rep_rf = classification_report(y_test, y_pred_rf)

print(f"Accuracy (RF): {accuracy_rf}")
print(classification_rep_rf)
# Out:
# Accuracy (RF): 0.92
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.93        63
#            1       0.85      0.95      0.90        37
#
#     accuracy                           0.92       100
#    macro avg       0.91      0.93      0.92       100
# weighted avg       0.92      0.92      0.92       100
