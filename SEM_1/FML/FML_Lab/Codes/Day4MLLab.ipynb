# %%
x = 'This is a String'
print(x[0])
print(x[0:1])
print(x[-1])
print(x[-2])
print(x[-4:-2])
print(x[:3])
print(x[3:])
# Out:
# T
# T
# g
# n
# ri
# Thi
# s is a String

# %%
fn = 'MSIS'
ln = "Manipal"
print(fn + " " + ln)
# Out:
# MSIS Manipal

# %%
print(fn*3)
# Out:
# MSISMSISMSIS

# %%
print('is' in fn)
print('IS' in fn)
# Out:
# False
# True

# %%
from re import L
Fn = 'Tom Mitchell Machine Learning Scientist'.split(' ')[0]
Mn = 'Tom Mitchell Machine Learning Scientist'.split(' ')[1]
Ln = 'Tom Mitchell Machine Learning Scientist'.split(' ')[-1]
print(Fn)
print(Mn)
print(Ln)
print(Fn+' '+Mn+' '+Ln)
# Out:
# Tom
# Mitchell
# Scientist
# Tom Mitchell Scientist

# %%
strnumasstr = 'chris'+'2'
print(strnumasstr)
# Out:
# chris2

# %%
strplusnum = 'chris'+2
print(strplusnum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-26abf90e8cb2> in <cell line: 1>()
# ----> 1 strplusnum = 'chris'+2
#       2 print(strplusnum)
#
# TypeError: can only concatenate str (not "int") to str

# %%
'chris'+str(2)
# Out:
# 'chris2'

# %%
x = {'a':1,'b':2}
type(x)
x['a']
x['b']
#x['1']
x['c']=-1
x
# Out:
# {'a': 1, 'b': 2, 'c': -1}

# %%
for key in x:
    print(key)
    print(x[key])
# Out:
# a
# 1
# b
# 2
# c
# -1

# %%
for num in x.values():
    print(num)
# Out:
# 1
# 2
# -1

# %%
x = ('Tom','Mitchell','Machine Learning Scientist','LA')
fn,ln,title,location = x
print(fn)
print(ln)
print(title)
print(location)
# Out:
# Tom
# Mitchell
# Machine Learning Scientist
# LA

# %%
sales_record = {
    'price':3.24,
    'num_items':4,
    'person':'Tom',
    'email':'Tom@ua.com'
}

# %%
sales_statememnt = '{} bought {} items at a price of INR {} for each for a total of INR {}'
print(sales_statememnt.format(sales_record['person'],
                              sales_record['num_items'],
                              sales_record['price'],
                              sales_record['num_items']*sales_record['price']))
# Out:
# Tom bought 4 items at a price of INR 3.24 for each for a total of INR 12.96

# %%
import datetime as dt
import time as tm
from datetime import date
from datetime import time
from datetime import datetime

# %%
date = dt.datetime.now()
date
tm.time()
# Out:
# 1724133003.5014405

# %%
Today = date.today()
print('Today is: ',Today)
# Out:
# Today is:  2024-08-20

# %%
dtnow = dt.datetime.fromtimestamp(tm.time())
dtnow
# Out:
# datetime.datetime(2024, 8, 20, 5, 53, 18, 6779)

# %%
dtnow.year,dtnow.month,dtnow.day,dtnow.hour,dtnow.minute,dtnow.second
# Out:
# (2024, 8, 20, 5, 53, 18)

# %%
delta = dt.timedelta(days = 30)

# %%
Today - delta
# Out:
# datetime.date(2024, 7, 21)

# %%
Today > Today - delta
# Out:
# True

# %%
class Person:
  institue = 'Manipal School of Information Science'

  def set_name(self,New_name):
    self.name = New_name
  def set_location(self,New_location):
    self.location = New_location

# %%
person = Person()
person.set_name('Nikhil S G')
person.set_location('Manipal')

# %%
print('{} lives in {} and studys in the institue {}'.format(person.name,person.location,person.institue))
# Out:
# Nikhil S G lives in Manipal and studys in the institue Manipal School of Information Science

# %%
x = {1,'x',2,'y',(1,2,3),'Hello'}
y = (1,2,3)
type(x)
type(y)
# Out:
# <class 'set'>
# <class 'tuple'>

# %%
a = {'One','X',2,'Y',3}
b = {1, 'X', 'Two', 'Y',"Three"}
print(a,b)
# Out:
# {2, 3, 'X', 'Y', 'One'} {1, 'X', 'Y', 'Three', 'Two'}

# %%
a.add('Three')
print(a)
b.add(3)
print(b)
# Out:
# {2, 3, 'X', 'Y', 'One', 'Three'}
# {1, 'X', 3, 'Y', 'Three', 'Two'}

# %%
from math import cos
store1= [10.00,11.00,12.34,2.34]
store2= [9.00,11.10,12.34,2.01]
store3= [10.00,11.00,12.34,2.01]
cheapest = map(min,store1,store2,store3)
costly = map(max,store1,store2,store3)
print(cheapest)
print(costly)

# %%
for item in cheapest:
    print(item)
# Out:
# 9.0
# 11.0
# 12.34
# 2.01

# %%
for item in costly:
    print(item)
# Out:
# 10.0
# 11.1
# 12.34
# 2.34

# %%
def cal(x):
    return x*x

# %%
num = (1,2,3,4)
res = map(cal,num)
print(res)

# %%
print(list(res))
# Out:
# [1, 4, 9, 16]

# %%
numb = (1,2,3,4)
resu = map(lambda x:x*x,numb)
print(resu)
print(list(resu))
# Out:
# ...
# [1, 4, 9, 16]

# %%
n1 = [1,2,3]
n2 = [4,5,6]
res = map(lambda x,y:x+y,n1,n2)
print(res)
print(list(res))
# Out:
# ...
# [5, 7, 9]
